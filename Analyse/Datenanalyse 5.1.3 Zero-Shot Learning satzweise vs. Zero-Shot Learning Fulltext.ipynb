# %% [markdown]
# # Data Combiner
#
# Here we try to bring together all the data into one clean dataframe

# %%
# !pip install pandas_profiling
# !pip install ipywidgets

# %%
import pandas as pd
import os
import plotly.express as px
import numpy as np

# %%
from pandas_profiling import ProfileReport
from statistics import mean
from scipy.stats import f_oneway

# %%
result = pd.read_csv(r"G:\Meine Ablage\HSLU\Master\Master Thesis\Coding Area\Data\result.csv", index_col=0)
result_normal = result[result["Report Type"]=="Normal Report"]

# %%
result_normal[0:1]
# Out:
#               Company           Label  \
# 0  child_cocoa_school  sustainability
#
#    Fulltext Cosine Similarity Wiki Summary  \
# 0                                  0.54579
#
#    Fulltext Cosine Similarity Human Rights  Zero Shot Fulltext  \
# 0                                  0.54579            0.242261
#
#                                      PDF Name  \
# 0  nestle-tackling-child-labor-report-2019-en
#
#                                               TF-IDF  \
# 0  [('child', 0.3676919823097556), ('report', 0.2...
#
#                                          Top N Words    Report Type  \
# 0  [('child', 391), ('cocoa', 146), ('school', 14...  Normal Report
#
#           Sentence Cosine Similarity Wiki Summarized  \
# 0  [tensor([[0.0519]]), tensor([[0.0648]]), tenso...
#
#    Sentence Cosine Similarity Wiki Summarized Mean  \
# 0                                            0.065
#
#    Sentence Cosine Similarity Wiki Summarized Mean Threshold 0  \
# ...

# %% [markdown]
# ### 5.1.3	Zero-Shot Learning satzweise vs. Zero Shots Learning Fulltext

# %%
result_prep = result_normal[["Zero Shot Fulltext", "Zero Shot Learning Sentence Mean Threshold"]]
result_prep_melt = result_prep.melt(var_name="Data")
fig = px.box(result_prep_melt, y="value", points="all", color = "Data", width=900)
fig.update_layout(legend=dict(
    yanchor="bottom",
    y=1,
    xanchor="left",
    x=0.01
))

fig.show()

# %%
fig = px.box(result_normal, y="Zero Shot Learning Sentence Mean Threshold", points="all", color = "Label", width=900)
# fig.update_layout(legend=dict(
#     yanchor="bottom",
#     y=1,
#     xanchor="left",
#     x=0.01
# ))

fig.show()

# %%
result_normal[0:1]
# Out:
#               Company           Label  \
# 0  child_cocoa_school  sustainability
#
#    Fulltext Cosine Similarity Wiki Summary  \
# 0                                  0.54579
#
#    Fulltext Cosine Similarity Human Rights  Zero Shot Fulltext  \
# 0                                  0.54579            0.242261
#
#                                      PDF Name  \
# 0  nestle-tackling-child-labor-report-2019-en
#
#                                               TF-IDF  \
# 0  [('child', 0.3676919823097556), ('report', 0.2...
#
#                                          Top N Words    Report Type  \
# 0  [('child', 391), ('cocoa', 146), ('school', 14...  Normal Report
#
#           Sentence Cosine Similarity Wiki Summarized  \
# 0  [tensor([[0.0519]]), tensor([[0.0648]]), tenso...
#
#    Sentence Cosine Similarity Wiki Summarized Mean  \
# 0                                            0.065
#
#    Sentence Cosine Similarity Wiki Summarized Mean Threshold 0  \
# ...

# %%
fig = px.scatter(result_normal, x="Zero Shot Learning Sentence Mean Threshold", y="Zero Shot Fulltext", trendline = "ols")
fig.show()
results = px.get_trendline_results(fig)
print(results)

results.px_fit_results.iloc[0].summary()
# Out:
#                                       px_fit_results
# 0  <statsmodels.regression.linear_model.Regressio...
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.304
# Method:                 Least Squares   F-statistic:                     236.1
# Date:                Wed, 14 Dec 2022   Prob (F-statistic):           1.96e-44
# Time:                        13:52:34   Log-Likelihood:                 632.47
# No. Observations:                 540   AIC:                            -1261.
# Df Residuals:                     538   BIC:                            -1252.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
fig = px.scatter(result_normal, x="Zero Shot Learning Sentence Mean Threshold", y="Zero Shot Fulltext", color="Label")
fig.show()
