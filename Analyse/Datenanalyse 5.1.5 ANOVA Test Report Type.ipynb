# %% [markdown]
# # Data Combiner
#
# Here we try to bring together all the data into one clean dataframe

# %%
# !pip install pandas_profiling
# !pip install ipywidgets

# %%
import pandas as pd
import os
import plotly.express as px
import numpy as np

# %%
from pandas_profiling import ProfileReport
from statistics import mean
from scipy.stats import f_oneway

# %%
result = pd.read_csv(r"G:\Meine Ablage\HSLU\Master\Master Thesis\Coding Area\Data\result.csv", index_col=0)
result = result[result["Report Type"]=="Normal Report"]

# %%
result[0:1]
# Out:
#               Company           Label  \
# 0  child_cocoa_school  sustainability
#
#    Fulltext Cosine Similarity Wiki Summary  \
# 0                                  0.54579
#
#    Fulltext Cosine Similarity Human Rights  Zero Shot Fulltext  \
# 0                                  0.54579            0.242261
#
#                                      PDF Name  \
# 0  nestle-tackling-child-labor-report-2019-en
#
#                                               TF-IDF  \
# 0  [('child', 0.3676919823097556), ('report', 0.2...
#
#                                          Top N Words    Report Type  \
# 0  [('child', 391), ('cocoa', 146), ('school', 14...  Normal Report
#
#           Sentence Cosine Similarity Wiki Summarized  \
# 0  [tensor([[0.0519]]), tensor([[0.0648]]), tenso...
#
#    Sentence Cosine Similarity Wiki Summarized Mean  \
# 0                                            0.065
#
#    Sentence Cosine Similarity Wiki Summarized Mean Threshold 0  \
# 0                                               0.11
#
#   Sentence by Sentence Cosine Similarity human rights  \
# 0  [tensor([[0.0519]]), tensor([[0.0648]]), tenso...
#
#    Sentence by Sentence Cosine Similarity human rights mean  \
# 0                                              0.065
#
#    Sentence by Sentence Cosine Similarity human rights Mean Threshold 0  \
# 0                                               0.11
#
#                      Zero Shot Learning Sentence Raw  \
# 0  [0.7845346331596375, 0.8715912103652954, 0.683...
#
#                                      Classified Text  \
# 0  ['Tackling Child Labor Report Continuing our c...
#
#    Zero Shot Learning Sentence Mean  \
# 0                             0.501
#
#    Zero Shot Learning Sentence Mean Threshold
# 0                                       0.501

# %% [markdown]
# ### 5.1.5	ANOVA-Test Unterscheidung der Report Typen

# %% [markdown]
# #### Zero Shot Fulltext

# %%
from scipy.stats import bartlett

column = "Zero Shot Fulltext"
normal_reports = result[result["Report Type"] == "Normal Report"][column]
de_reports = result[result["Report Type"] == "DE"][column]
fake_reports = result[result["Report Type"] == "Fake"][column]

stat, p = bartlett(normal_reports, de_reports, fake_reports)
p
# Out:
# 0.9688408143275081

# %%
fig = px.box(result, y="Zero Shot Fulltext", points="all", color = "Report Type", width=800)
fig.update_layout(legend=dict(
    yanchor="bottom",
    y=1,
    xanchor="left",
    x=0.01
))
fig.show()

# %%
column = "Zero Shot Fulltext"
normal_reports = result[result["Report Type"] == "Normal Report"][column]
de_reports = result[result["Report Type"] == "DE"][column]
fake_reports = result[result["Report Type"] == "Fake"][column]

f_oneway(normal_reports, de_reports, fake_reports)
# Out:
# F_onewayResult(statistic=3.561819774978207e-14, pvalue=0.9999999999999354)

# %% [markdown]
# #### Zero Shot Learning Sentence by Sentcne

# %%
from scipy.stats import bartlett

column = "Zero Shot Learning Sentence Mean Threshold"
normal_reports = result[result["Report Type"] == "Normal Report"][column]
de_reports = result[result["Report Type"] == "DE"][column]
fake_reports = result[result["Report Type"] == "Fake"][column]

stat, p = bartlett(normal_reports, de_reports, fake_reports)
p
# Out:
# 0.00018315041646841616

# %%
fig = px.box(result, y="Zero Shot Learning Sentence Mean Threshold", points="all", color = "Report Type", width=800)
fig.update_layout(legend=dict(
    yanchor="bottom",
    y=1,
    xanchor="left",
    x=0.01
))
fig.show()

# %%
column = "Zero Shot Learning Sentence Mean Threshold"
normal_reports = result[result["Report Type"] == "Normal Report"][column]
de_reports = result[result["Report Type"] == "DE"][column]
fake_reports = result[result["Report Type"] == "Fake"][column]

f_oneway(normal_reports, de_reports, fake_reports)
# Out:
# F_onewayResult(statistic=5.048998122433164, pvalue=0.006699670543844871)

# %% [markdown]
# ####	Sentence-BERT Similarität ANOVA Test der Report Typen

# %%
from scipy.stats import bartlett

column = "Sentence Cosine Similarity Wiki Summarized Mean Threshold 0"
normal_reports = result[result["Report Type"] == "Normal Report"][column]
de_reports = result[result["Report Type"] == "DE"][column]
fake_reports = result[result["Report Type"] == "Fake"][column]

stat, p = bartlett(normal_reports, de_reports, fake_reports)
p
# Out:
# 0.00018315041646841616

# %%
fig = px.box(result, y="Sentence Cosine Similarity Wiki Summarized Mean Threshold 0", points="all", color = "Report Type", width=800)
fig.update_layout(legend=dict(
    yanchor="bottom",
    y=1,
    xanchor="left",
    x=0.01
))
fig.show()

# %%
column = "Sentence Cosine Similarity Wiki Summarized Mean Threshold 0"
normal_reports = result[result["Report Type"] == "Normal Report"][column]
de_reports = result[result["Report Type"] == "DE"][column]
fake_reports = result[result["Report Type"] == "Fake"][column]

stats.kruskal(normal_reports, de_reports, fake_reports)
# Out:
# KruskalResult(statistic=11.833000572775289, pvalue=0.00269461407192475)
