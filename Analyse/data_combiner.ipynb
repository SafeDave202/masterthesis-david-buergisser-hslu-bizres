# %% [markdown]
# # Data Combiner
#
# Hier fliessen alle Daten in ein Dataframe

# %% [markdown]
# ### Zuerst werden die nötigen Libraries installiert und importiert

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: streamlit==1.14.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: pandas==1.4.3 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 2)) (1.4.3)
# Requirement already satisfied: numpy==1.23.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 3)) (1.23.2)
# Requirement already satisfied: plotly==5.10.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 4)) (5.10.0)
# Requirement already satisfied: streamlit-option-menu==0.3.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 5)) (0.3.2)
# Requirement already satisfied: streamlit-aggrid==0.0.4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: opencv-python==4.6.0.66 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 7)) (4.6.0.66)
# Requirement already satisfied: Wikipedia-API==0.5.4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 8)) (0.5.4)
# Requirement already satisfied: transformers==4.24.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 9)) (4.24.0)
# Requirement already satisfied: torch==1.12.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 10)) (1.12.1)
# Requirement already satisfied: torchvision==0.13.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 11)) (0.13.1)
# Requirement already satisfied: statsmodels==0.13.5 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 12)) (0.13.5)
# Requirement already satisfied: spacy==3.4.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 13)) (3.4.2)
# Requirement already satisfied: spacy-legacy==3.0.10 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 14)) (3.0.10)
# Requirement already satisfied: spacy-loggers==1.0.3 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 15)) (1.0.3)
# Requirement already satisfied: scikit-learn==1.1.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 16)) (1.1.2)
# Requirement already satisfied: sentence-transformers==2.2.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 17)) (2.2.2)
# Requirement already satisfied: seaborn==0.12.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 18)) (0.12.1)
# Requirement already satisfied: requests==2.28.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 19)) (2.28.1)
# Requirement already satisfied: regex==2022.8.17 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 20)) (2022.8.17)
# Requirement already satisfied: Pillow==9.2.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 21)) (9.2.0)
# Requirement already satisfied: pdfminer3==2018.12.3.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 22)) (2018.12.3.0)
# Requirement already satisfied: pandas-profiling==3.5.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 23)) (3.5.0)
# Requirement already satisfied: openpyxl==3.0.10 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 24)) (3.0.10)
# Requirement already satisfied: nltk==3.7 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 25)) (3.7)
# Requirement already satisfied: matplotlib==3.5.3 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 26)) (3.5.3)
# Requirement already satisfied: huggingface-hub==0.10.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 27)) (0.10.1)
# Requirement already satisfied: gensim==4.2.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 28)) (4.2.0)
# Requirement already satisfied: bs4==0.0.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from -r requirements.txt (line 29)) (0.0.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (4.3.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (12.6.0)
# Requirement already satisfied: altair>=3.2.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (4.2.0)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (10.0.0)
# Requirement already satisfied: importlib-metadata>=1.4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (4.10.0)
# Requirement already satisfied: protobuf<4,>=3.12 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: cachetools>=4.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: watchdog in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (2.1.9)
# Requirement already satisfied: packaging>=14.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: gitpython!=3.1.19 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (3.1.29)
# Requirement already satisfied: toml in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (4.2)
# Requirement already satisfied: python-dateutil in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: validators>=0.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (0.8.0b4)
# Requirement already satisfied: click>=7.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (8.1.3)
# Requirement already satisfied: semver in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pympler>=0.9 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: blinker>=1.0.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (1.5)
# Requirement already satisfied: tornado>=5.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from streamlit==1.14.0->-r requirements.txt (line 1)) (6.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pandas==1.4.3->-r requirements.txt (line 2)) (2022.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from plotly==5.10.0->-r requirements.txt (line 4)) (8.0.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from transformers==4.24.0->-r requirements.txt (line 9)) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from transformers==4.24.0->-r requirements.txt (line 9)) (6.0)
# Requirement already satisfied: filelock in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from transformers==4.24.0->-r requirements.txt (line 9)) (3.8.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from transformers==4.24.0->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: scipy>=1.3 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from statsmodels==0.13.5->-r requirements.txt (line 12)) (1.9.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from statsmodels==0.13.5->-r requirements.txt (line 12)) (0.5.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (3.0.7)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (0.6.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (2.0.8)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (0.4.2)
# Requirement already satisfied: jinja2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (3.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (1.9.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (3.3.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (8.1.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (0.10.1)
# Requirement already satisfied: setuptools in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (58.1.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (1.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from spacy==3.4.2->-r requirements.txt (line 13)) (2.4.4)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.1.2->-r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==1.1.2->-r requirements.txt (line 16)) (3.1.0)
# Requirement already satisfied: sentencepiece in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers==2.2.2->-r requirements.txt (line 17)) (0.1.97)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1->-r requirements.txt (line 19)) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1->-r requirements.txt (line 19)) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1->-r requirements.txt (line 19)) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from requests==2.28.1->-r requirements.txt (line 19)) (1.22)
# Requirement already satisfied: pycryptodome in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pdfminer3==2018.12.3.0->-r requirements.txt (line 22)) (3.15.0)
# Requirement already satisfied: sortedcontainers in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pdfminer3==2018.12.3.0->-r requirements.txt (line 22)) (2.4.0)
# Requirement already satisfied: chardet in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pdfminer3==2018.12.3.0->-r requirements.txt (line 22)) (3.0.4)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pandas-profiling==3.5.0->-r requirements.txt (line 23)) (0.12.2)
# Requirement already satisfied: typeguard<2.14,>=2.13.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pandas-profiling==3.5.0->-r requirements.txt (line 23)) (2.13.3)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pandas-profiling==3.5.0->-r requirements.txt (line 23)) (0.7.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pandas-profiling==3.5.0->-r requirements.txt (line 23)) (0.1.12)
# Requirement already satisfied: multimethod<1.10,>=1.4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from pandas-profiling==3.5.0->-r requirements.txt (line 23)) (1.9)
# Requirement already satisfied: et-xmlfile in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from openpyxl==3.0.10->-r requirements.txt (line 24)) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.3->-r requirements.txt (line 26)) (4.37.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.3->-r requirements.txt (line 26)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.3->-r requirements.txt (line 26)) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from matplotlib==3.5.3->-r requirements.txt (line 26)) (3.0.6)
# Requirement already satisfied: Cython==0.29.28 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from gensim==4.2.0->-r requirements.txt (line 28)) (0.29.28)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from gensim==4.2.0->-r requirements.txt (line 28)) (5.2.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from bs4==0.0.1->-r requirements.txt (line 29)) (4.11.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling==3.5.0->-r requirements.txt (line 23)) (0.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling==3.5.0->-r requirements.txt (line 23)) (2.8.8)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling==3.5.0->-r requirements.txt (line 23)) (21.2.0)
# Requirement already satisfied: imagehash in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling==3.5.0->-r requirements.txt (line 23)) (4.3.1)
# Requirement already satisfied: toolz in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from altair>=3.2.0->streamlit==1.14.0->-r requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from altair>=3.2.0->streamlit==1.14.0->-r requirements.txt (line 1)) (4.3.2)
# Requirement already satisfied: entrypoints in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from altair>=3.2.0->streamlit==1.14.0->-r requirements.txt (line 1)) (0.3)
# Requirement already satisfied: colorama in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from click>=7.0->streamlit==1.14.0->-r requirements.txt (line 1)) (0.4.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from gitpython!=3.1.19->streamlit==1.14.0->-r requirements.txt (line 1)) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=1.4->streamlit==1.14.0->-r requirements.txt (line 1)) (3.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from jinja2->spacy==3.4.2->-r requirements.txt (line 13)) (2.0.1)
# Requirement already satisfied: six in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from patsy>=0.5.2->statsmodels==0.13.5->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->streamlit==1.14.0->-r requirements.txt (line 1)) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from rich>=10.11.0->streamlit==1.14.0->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy==3.4.2->-r requirements.txt (line 13)) (0.7.8)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from tzlocal>=1.1->streamlit==1.14.0->-r requirements.txt (line 1)) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from tzlocal>=1.1->streamlit==1.14.0->-r requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from validators>=0.2->streamlit==1.14.0->-r requirements.txt (line 1)) (5.1.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->bs4==0.0.1->-r requirements.txt (line 29)) (2.3.2.post1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.14.0->-r requirements.txt (line 1)) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.14.0->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: PyWavelets in c:\users\daveb\appdata\local\programs\python\python310\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling==3.5.0->-r requirements.txt (line 23)) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import os
import plotly.express as px
import numpy as np

# %%
from statistics import mean
from scipy.stats import f_oneway

# %%
result_combiner = []

# %% [markdown]
# ### Zero Shot Learning Fulltext

# %%
topic_modeler = os.listdir(r"..\Data\Resultate\Zero Shot Learning Fulltext")
# Out:
# ['abb_sustainability_performanceFullText_TopicModeling.csv',
#  'adecco_group_cidFullText_TopicModeling.csv',
#  'allreal_report_employeeFullText_TopicModeling.csv',
#  'aluminium_tadjikistan_glencoreFullText_TopicModeling.csv',
#  'amag_aluminium_austriaFullText_TopicModeling.csv',
#  'america_rome_romanFullText_TopicModeling.csv',
#  'axa_health_customerFullText_TopicModeling.csv',
#  'baloise_risk_managementFullText_TopicModeling.csv',
#  'bcge_financial_boardFullText_TopicModeling.csv',
#  'bell_food_groupFullText_TopicModeling.csv',
#  'bouygues_sustainability_reportFullText_TopicModeling.csv',
#  'braun_employee_managementFullText_TopicModeling.csv',
#  'bucher_industries_employeeFullText_TopicModeling.csv',
#  'business_avaloq_reportFullText_TopicModeling.csv',
#  'celgene_report_employeeFullText_TopicModeling.csv',
#  'chemical_mitsubishi_employeeFullText_TopicModeling.csv',
#  'child_cocoa_schoolFullText_TopicModeling.csv',
#  'cid_burckhardt_compressionFullText_TopicModeling.csv',
#  'cid_client_riskFullText_TopicModeling.csv',
#  'clariant_business_clariantsFullText_TopicModeling.csv',
#  'community_glencore_reportFullText_TopicModeling.csv',
#  'company_apollo_employeeFullText_TopicModeling.csv',
#  'company_water_cocacolaFullText_TopicModeling.csv',
#  'coop_sustainability_productFullText_TopicModeling.csv',
#  'coop_target_groupFullText_TopicModeling.csv',
#  'credit_risk_suisseFullText_TopicModeling.csv',
#  'decathlon_product_productionFullText_TopicModeling.csv',
#  'dental_report_productionFullText_TopicModeling.csv',
#  'die_der_unsereFullText_TopicModeling.csv',
#  'die_der_werdenFullText_TopicModeling.csv',
#  'die_gkb_derFullText_TopicModeling.csv',
#  'die_lindt_sprüngliFullText_TopicModeling.csv',
#  'die_ruag_unsereFullText_TopicModeling.csv',
#  'die_volg_derFullText_TopicModeling.csv',
#  'die_würth_derFullText_TopicModeling.csv',
#  'diligence_supply_chainFullText_TopicModeling.csv',
#  'dsv_employee_targetFullText_TopicModeling.csv',
#  'dufry_customer_airportFullText_TopicModeling.csv',
#  'easyjet_year_millionFullText_TopicModeling.csv',
#  'effective_said_millionFullText_TopicModeling.csv',
#  'efg_company_engagementFullText_TopicModeling.csv',
#  'energy_emission_electricityFullText_TopicModeling.csv',
#  'energy_emission_googleFullText_TopicModeling.csv',
#  'energy_solutions_companyFullText_TopicModeling.csv',
#  'environment_employee_processFullText_TopicModeling.csv',
#  'feed_cargill_nutritionFullText_TopicModeling.csv',
#  'feintool_employee_companyFullText_TopicModeling.csv',
#  'financial_sap_managementFullText_TopicModeling.csv',
#  'financial_swiss_employeeFullText_TopicModeling.csv',
#  'football_german_teamFullText_TopicModeling.csv',
#  'football_uefa_socialFullText_TopicModeling.csv',
#  'ge_business_energyFullText_TopicModeling.csv',
#  'gf_sustainability_reportFullText_TopicModeling.csv',
#  'girsberger_product_employeeFullText_TopicModeling.csv',
#  'givaudan_material_approachFullText_TopicModeling.csv',
#  'glarner_kantonalbank_dieFullText_TopicModeling.csv',
#  'glencore_water_reportFullText_TopicModeling.csv',
#  'global_safety_trainingFullText_TopicModeling.csv',
#  'global_training_qsheFullText_TopicModeling.csv',
#  'group_autogrill_managementFullText_TopicModeling.csv',
#  'group_sfs_employeeFullText_TopicModeling.csv',
#  'group_sustainability_supplierFullText_TopicModeling.csv',
#  'group_swatch_energyFullText_TopicModeling.csv',
#  'group_zegna_supplierFullText_TopicModeling.csv',
#  'hochdorf_financial_groupFullText_TopicModeling.csv',
#  'hp_product_impactFullText_TopicModeling.csv',
#  'ikea_business_positiveFullText_TopicModeling.csv',
#  'implenia_die_derFullText_TopicModeling.csv',
#  'investment_group_partnersFullText_TopicModeling.csv',
#  'investment_sustainability_reportFullText_TopicModeling.csv',
#  'lombard_odier_sustainabilityFullText_TopicModeling.csv',
#  'lyreco_sustainability_productFullText_TopicModeling.csv',
#  'mediclinic_group_employeeFullText_TopicModeling.csv',
#  'meyer_burger_employeeFullText_TopicModeling.csv',
#  'model_number_tonneFullText_TopicModeling.csv',
#  'novartis_water_energyFullText_TopicModeling.csv',
#  'orior_sustainability_productFullText_TopicModeling.csv',
#  'palace_race_buckinghamFullText_TopicModeling.csv',
#  'people_sustainability_reportFullText_TopicModeling.csv',
#  'product_calida_materialFullText_TopicModeling.csv',
#  'product_smokefree_tobaccoFullText_TopicModeling.csv',
#  'property_sustainability_tenantFullText_TopicModeling.csv',
#  'reuters_thomson_globalFullText_TopicModeling.csv',
#  'risk_dxc_customerFullText_TopicModeling.csv',
#  'roche_committee_yearFullText_TopicModeling.csv',
#  'schindler_report_productFullText_TopicModeling.csv',
#  'sfs_group_employeeFullText_TopicModeling.csv',
#  'sika_sustainability_riskFullText_TopicModeling.csv',
#  'sind_der_dieFullText_TopicModeling.csv',
#  'stadler_employee_sustainabilityFullText_TopicModeling.csv',
#  'starrag_group_yearFullText_TopicModeling.csv',
#  'sulzer_financial_reportFullText_TopicModeling.csv',
#  'sunrise_financial_boardFullText_TopicModeling.csv',
#  'sustainability_allianz_riskFullText_TopicModeling.csv',
#  'sustainability_bank_reportFullText_TopicModeling.csv',
#  'sustainability_employee_businessFullText_TopicModeling.csv',
#  'sustainability_iic_reportFullText_TopicModeling.csv',
#  'sustainability_report_businessFullText_TopicModeling.csv',
#  'sustainability_report_logitechFullText_TopicModeling.csv',
#  'sustainability_risk_reportFullText_TopicModeling.csv',
#  'swiss_life_sustainabilityFullText_TopicModeling.csv',
#  'swiss_post_reportFullText_TopicModeling.csv',
#  'swiss_risk_sustainabilityFullText_TopicModeling.csv',
#  'swiss_sustainability_riskFullText_TopicModeling.csv',
#  'syngenta_report_agricultureFullText_TopicModeling.csv',
#  'takeda_patient_businessFullText_TopicModeling.csv',
#  'target_reach_certificationFullText_TopicModeling.csv',
#  'team_manager_designFullText_TopicModeling.csv',
#  'temenos_financial_yearFullText_TopicModeling.csv',
#  'ubp_sustainability_investmentFullText_TopicModeling.csv',
#  'valora_financial_groupFullText_TopicModeling.csv',
#  'value_nestlé_progressFullText_TopicModeling.csv',
#  'vifor_pharma_patientFullText_TopicModeling.csv',
#  'volvo_group_financialFullText_TopicModeling.csv',
#  'water_carbon_wasteFullText_TopicModeling.csv',
#  'water_employee_managementFullText_TopicModeling.csv',
#  'year_richemont_groupFullText_TopicModeling.csv',
#  'zurich_commitment_insuranceFullText_TopicModeling.csv']

# %%
topic_modeler = os.listdir(r"..\Data\Resultate\Zero Shot Learning Fulltext")

topic_modeler_list = []

for file in topic_modeler:
    df_topic_modeler = pd.read_csv(
        fr"..\Data\Resultate\Zero Shot Learning Fulltext\{file}", index_col=0) 
    df_topic_modeler = df_topic_modeler.rename(columns={"Score": "Zero Shot Fulltext",})
    new_col = file[:-26]
    df_topic_modeler['Label'] = df_topic_modeler['Label'].replace({'employee affairs': 'labour law'})
    # print(new_col)

    idx = 0
    df_topic_modeler.insert(loc=idx, column='Company', value=new_col)
    topic_modeler_list.append(df_topic_modeler)  

df_topic_modeler = pd.concat(topic_modeler_list)
result_combiner.append(df_topic_modeler)

# %%
df_topic_modeler.head()
# Out:
#                           Company           Label  Zero Shot Fulltext
# 0  abb_sustainability_performance   social issues            0.249538
# 1  abb_sustainability_performance    human rights            0.226750
# 2  abb_sustainability_performance  sustainability            0.224777
# 3  abb_sustainability_performance      labour law            0.215665
# 4  abb_sustainability_performance           fraud            0.083270

# %% [markdown]
# ### Sentence-BERT satzweise

# %%
sentence_cosine_similarity = os.listdir(r"..\Data\Resultate\Sentence by Sentence Cosine Similarity raw")

sentence_cosine_similarity_list = []

for file in sentence_cosine_similarity:
    # if file[-27:-4] == "FullText_Cosine_Scoring":
    df_sentence_cosine_similarity_list_list = pd.read_csv(
        fr"..\Data\Resultate\Sentence by Sentence Cosine Similarity raw\{file}", index_col=0)
    df_sentence_cosine_similarity_list_list = df_sentence_cosine_similarity_list_list.rename(columns={"Cosine Similarity Mean": "Sentence Cosine Similarity Wiki Summarized",})
    new_col = file[:-15]
    # print(new_col)
    idx = 0
    df_sentence_cosine_similarity_list_list.insert(loc=idx, column='Company', value=new_col)
    sentence_cosine_similarity_list.append(df_sentence_cosine_similarity_list_list)

df_sentence_cosine_similarity_list_list = pd.concat(sentence_cosine_similarity_list)
result_combiner.append(df_sentence_cosine_similarity_list_list)
len(df_sentence_cosine_similarity_list_list)
# Out:
# 590

# %% [markdown]
# Mean Calculation
#
# Hier werden die Durchschnitte errechnet

# %%
cosine_mean = []
cosine_results = df_sentence_cosine_similarity_list_list["Sentence Cosine Similarity Wiki Summarized"].tolist()
for element in cosine_results:
    test = element
    test_2 = test[1:-1]
    new_test = test_2.split(", ")
    non_tensor_list = []

    for subelement in new_test:
        non_tensor_list.append(float(subelement[9:14]))
    mean_result = round(mean(non_tensor_list), 3)
    cosine_mean.append(mean_result)

# %%
len(cosine_mean)
# Out:
# 590

# %%
df_sentence_cosine_similarity_list_list["Sentence Cosine Similarity Wiki Summarized Mean"] = cosine_mean
df_sentence_cosine_similarity_list_list.head()
result_combiner.append(df_sentence_cosine_similarity_list_list)

# %%
def mean_cosine_calculator(cosine_results):

    non_tensor_list = []
    for element in cosine_results:
        test = element
        test_2 = test[1:-1]
        new_test = test_2.split(", ")
        new_list = []
        for element in new_test:
            new_list.append(element[9:14])
            string_element = str(element[0])
            non_tensor_list.append(float(string_element[8:14]))

    mean_result = round(mean(non_tensor_list))

# %% [markdown]
# Hier werden die Means mit einem Schwellenwert (Threshold) von 0 berechnet (Keine negativen Zahlen)
# Falls ein Label einen Wert unter 0 bekommen würde, wird dieser zu 0.05 gemacht. Dies würde sonst komische Ergebnisse geben.

# %%
cosine_mean_threshold = []
cosine_results_threshold = df_sentence_cosine_similarity_list_list["Sentence Cosine Similarity Wiki Summarized"].tolist()
for element in cosine_results_threshold:
    test = element
    test_2 = test[1:-1]
    new_test = test_2.split(", ")
    non_tensor_list = []

    for tensor in new_test:
        float_tensor = float(tensor[9:14])
        if float_tensor > 0.0:
            non_tensor_list.append(float_tensor)
        else:
            continue

    if len(non_tensor_list) == 0:
        non_tensor_list.append(0.05)

        
    mean_result = round(mean(non_tensor_list), 3)
    cosine_mean_threshold.append(mean_result)

# %%
len(cosine_mean_threshold)
# Out:
# 590

# %%
df_sentence_cosine_similarity_list_list["Sentence Cosine Similarity Wiki Summarized Mean Threshold 0"] = cosine_mean_threshold
df_sentence_cosine_similarity_list_list.head()
result_combiner.append(df_sentence_cosine_similarity_list_list)

# %% [markdown]
# ### Sentence-BERT satzweise Human Rights Alternative

# %%
sentence_cosine_similarity_hr = os.listdir(r"..\Data\Resultate\Sentence by Sentence Cosine Similarity raw human rights")

sentence_cosine_similarity_list_hr = []

for file in sentence_cosine_similarity_hr:
    # if file[-27:-4] == "FullText_Cosine_Scoring":
    df_sentence_cosine_similarity_list_hr = pd.read_csv(
        fr"..\Data\Resultate\Sentence by Sentence Cosine Similarity raw human rights\{file}", index_col=0)
    df_sentence_cosine_similarity_list_hr = df_sentence_cosine_similarity_list_hr.rename(columns={"Cosine Similarity Mean": "Sentence by Sentence Cosine Similarity human rights",})
    new_col = file[:-28]
    # print(new_col)
    idx = 0
    df_sentence_cosine_similarity_list_hr.insert(loc=idx, column='Company', value=new_col)
    sentence_cosine_similarity_list_hr.append(df_sentence_cosine_similarity_list_hr)

df_sentence_cosine_similarity_list_hr = pd.concat(sentence_cosine_similarity_list_hr)
# result_combiner.append(df_sentence_cosine_similarity_list_hr)
len(df_sentence_cosine_similarity_list_hr)
# Out:
# 590

# %%
df_sentence_cosine_similarity_list_hr.head()
# Out:
#                           Company           Label  \
# 0  abb_sustainability_performance  sustainability
# 1  abb_sustainability_performance    human rights
# 2  abb_sustainability_performance           fraud
# 3  abb_sustainability_performance   social issues
# 4  abb_sustainability_performance      labour law
#
#   Sentence by Sentence Cosine Similarity human rights
# 0  [tensor([[0.3533]]), tensor([[0.0915]]), tenso...
# 1  [tensor([[0.1359]]), tensor([[0.0887]]), tenso...
# 2  [tensor([[-0.0050]]), tensor([[0.0324]]), tens...
# 3  [tensor([[0.1108]]), tensor([[0.0350]]), tenso...
# 4  [tensor([[0.0646]]), tensor([[0.0733]]), tenso...

# %% [markdown]
# Mean Calculation
#
# Hier werden die Durchschnitte errechnet

# %%
cosine_mean = []
cosine_results = df_sentence_cosine_similarity_list_hr["Sentence by Sentence Cosine Similarity human rights"].tolist()
for element in cosine_results:
    test = element
    test_2 = test[1:-1]
    new_test = test_2.split(", ")
    non_tensor_list = []

    for subelement in new_test:
        non_tensor_list.append(float(subelement[9:14]))
    mean_result = round(mean(non_tensor_list), 3)
    cosine_mean.append(mean_result)

# %%
df_sentence_cosine_similarity_list_hr["Sentence by Sentence Cosine Similarity human rights mean"] = cosine_mean
df_sentence_cosine_similarity_list_hr.head()
# Out:
#                           Company           Label  \
# 0  abb_sustainability_performance  sustainability
# 1  abb_sustainability_performance    human rights
# 2  abb_sustainability_performance           fraud
# 3  abb_sustainability_performance   social issues
# 4  abb_sustainability_performance      labour law
#
#   Sentence by Sentence Cosine Similarity human rights  \
# 0  [tensor([[0.3533]]), tensor([[0.0915]]), tenso...
# 1  [tensor([[0.1359]]), tensor([[0.0887]]), tenso...
# 2  [tensor([[-0.0050]]), tensor([[0.0324]]), tens...
# 3  [tensor([[0.1108]]), tensor([[0.0350]]), tenso...
# 4  [tensor([[0.0646]]), tensor([[0.0733]]), tenso...
#
#    Sentence by Sentence Cosine Similarity human rights mean
# 0                                              0.169
# 1                                              0.098
# 2                                             -0.005
# 3                                              0.071
# 4                                              0.045

# %% [markdown]
# Hier werden die Means mit einem Schwellenwert (Threshold) von 0 berechnet (Keine negativen Zahlen)
# Falls ein Label einen Wert unter 0 bekommen würde, wird dieser zu 0.05 gemacht. Dies würde sonst komische Ergebnisse geben.

# %%
cosine_mean_threshold = []
cosine_results_threshold = df_sentence_cosine_similarity_list_hr["Sentence by Sentence Cosine Similarity human rights"].tolist()
for element in cosine_results_threshold:
    test = element
    test_2 = test[1:-1]
    new_test = test_2.split(", ")
    non_tensor_list = []

    for tensor in new_test:
        float_tensor = float(tensor[9:14])
        if float_tensor > 0.0:
            non_tensor_list.append(float_tensor)
        else:
            continue

    if len(non_tensor_list) == 0:
        non_tensor_list.append(0.05)

        
    mean_result = round(mean(non_tensor_list), 3)
    cosine_mean_threshold.append(mean_result)

len(cosine_mean_threshold)
# Out:
# 590

# %%
df_sentence_cosine_similarity_list_hr["Sentence by Sentence Cosine Similarity human rights Mean Threshold 0"] = cosine_mean_threshold
result_combiner.append(df_sentence_cosine_similarity_list_hr)
df_sentence_cosine_similarity_list_hr.head()
# Out:
#                           Company           Label  \
# 0  abb_sustainability_performance  sustainability
# 1  abb_sustainability_performance    human rights
# 2  abb_sustainability_performance           fraud
# 3  abb_sustainability_performance   social issues
# 4  abb_sustainability_performance      labour law
#
#   Sentence by Sentence Cosine Similarity human rights  \
# 0  [tensor([[0.3533]]), tensor([[0.0915]]), tenso...
# 1  [tensor([[0.1359]]), tensor([[0.0887]]), tenso...
# 2  [tensor([[-0.0050]]), tensor([[0.0324]]), tens...
# 3  [tensor([[0.1108]]), tensor([[0.0350]]), tenso...
# 4  [tensor([[0.0646]]), tensor([[0.0733]]), tenso...
#
#    Sentence by Sentence Cosine Similarity human rights mean  \
# 0                                              0.169
# 1                                              0.098
# 2                                             -0.005
# 3                                              0.071
# 4                                              0.045
#
#    Sentence by Sentence Cosine Similarity human rights Mean Threshold 0
# 0                                              0.188
# 1                                              0.125
# 2                                              0.062
# 3                                              0.104
# 4                                              0.106

# %% [markdown]
# ### Zero Shot Learning Satzweise

# %%
zero_shot_sentence = os.listdir(r"..\Data\Resultate\Zero Shot Learning Satzweise Raw")

zero_shot_sentence_list = []

for file in zero_shot_sentence:
    # if file[-27:-4] == "FullText_Cosine_Scoring":
    df_zero_shot_sentence = pd.read_csv(
        fr"..\Data\Resultate\Zero Shot Learning Satzweise Raw\{file}", index_col=0)
    df_zero_shot_sentence = df_zero_shot_sentence.rename(columns={"Zero Shot Score Raw": "Zero Shot Learning Sentence Raw",})
    new_col = file[:-25]
    # print(new_col)
    idx = 0
    df_zero_shot_sentence.insert(loc=idx, column='Company', value=new_col)
    zero_shot_sentence_list.append(df_zero_shot_sentence)

df_zero_shot_sentence = pd.concat(zero_shot_sentence_list)
# result_combiner.append(df_zero_shot_sentence)
df_zero_shot_sentence = df_zero_shot_sentence.drop("Classified Text", axis=1)
len(df_zero_shot_sentence)
# Out:
# 590

# %%
df_zero_shot_sentence.head()
# Out:
#                           Company           Label  \
# 0  abb_sustainability_performance  sustainability
# 1  abb_sustainability_performance    human rights
# 2  abb_sustainability_performance           fraud
# 3  abb_sustainability_performance   social issues
# 4  abb_sustainability_performance      labour law
#
#                      Zero Shot Learning Sentence Raw
# 0  [0.7101063132286072, 0.41432586312294006, 0.50...
# 1  [0.22032485902309418, 0.21426941454410553, 0.1...
# 2  [0.057856060564517975, 0.16787868738174438, 0....
# 3  [0.0063936966471374035, 0.1543944627046585, 0....
# 4  [0.005319107323884964, 0.049131620675325394, 0...

# %%
zero_shot_mean = []
zero_shot_results = df_zero_shot_sentence["Zero Shot Learning Sentence Raw"].tolist()
for element in zero_shot_results:
    test = element
    test_2 = test[1:-1]
    new_test = test_2.split(", ")
    non_tensor_list = []
    for subelement in new_test:
        non_tensor_list.append(float(subelement))
    mean_result = round(mean(non_tensor_list), 3)
    zero_shot_mean.append(mean_result)


len(zero_shot_mean)
# Out:
# 590

# %%
df_zero_shot_sentence["Zero Shot Learning Sentence Mean"] = zero_shot_mean
df_zero_shot_sentence.head()
# Out:
#                           Company           Label  \
# 0  abb_sustainability_performance  sustainability
# 1  abb_sustainability_performance    human rights
# 2  abb_sustainability_performance           fraud
# 3  abb_sustainability_performance   social issues
# 4  abb_sustainability_performance      labour law
#
#                      Zero Shot Learning Sentence Raw  \
# 0  [0.7101063132286072, 0.41432586312294006, 0.50...
# 1  [0.22032485902309418, 0.21426941454410553, 0.1...
# 2  [0.057856060564517975, 0.16787868738174438, 0....
# 3  [0.0063936966471374035, 0.1543944627046585, 0....
# 4  [0.005319107323884964, 0.049131620675325394, 0...
#
#    Zero Shot Learning Sentence Mean
# 0                             0.597
# 1                             0.161
# 2                             0.112
# 3                             0.086
# 4                             0.044

# %% [markdown]
# Hier werden die Means mit einem Schwellenwert (Threshold) von 0.1 berechnet. Nie tiefen Zahlen würden den Durchschnitt zu stark beeinträchtigen.
# Falls ein Label einen Wert unter 0 bekommen würde, wird dieser zu 0.05 gemacht. Dies würde sonst komische Ergebnisse geben.

# %%
zero_shot_mean_thresh = []
zero_shot_results = df_zero_shot_sentence["Zero Shot Learning Sentence Raw"].tolist()
for element in zero_shot_results:
    test = element
    test_2 = test[1:-1]
    new_test = test_2.split(", ")
    non_tensor_list = []
    for tensor in new_test:
        float_tensor = float(tensor)
        if float_tensor > 0.1:
            non_tensor_list.append(float_tensor)
        else:
            continue

    if len(non_tensor_list) == 0:
        non_tensor_list.append(0.05)

    mean_result = round(mean(non_tensor_list), 3)
    zero_shot_mean_thresh.append(mean_result)


len(zero_shot_mean_thresh)
# Out:
# 590

# %%
df_zero_shot_sentence["Zero Shot Learning Sentence Mean Threshold"] = zero_shot_mean_thresh
result_combiner.append(df_zero_shot_sentence)
df_zero_shot_sentence.head()
# Out:
#                           Company           Label  \
# 0  abb_sustainability_performance  sustainability
# 1  abb_sustainability_performance    human rights
# 2  abb_sustainability_performance           fraud
# 3  abb_sustainability_performance   social issues
# 4  abb_sustainability_performance      labour law
#
#                      Zero Shot Learning Sentence Raw  \
# 0  [0.7101063132286072, 0.41432586312294006, 0.50...
# 1  [0.22032485902309418, 0.21426941454410553, 0.1...
# 2  [0.057856060564517975, 0.16787868738174438, 0....
# 3  [0.0063936966471374035, 0.1543944627046585, 0....
# 4  [0.005319107323884964, 0.049131620675325394, 0...
#
#    Zero Shot Learning Sentence Mean  \
# 0                             0.597
# 1                             0.161
# 2                             0.112
# 3                             0.086
# 4                             0.044
#
#    Zero Shot Learning Sentence Mean Threshold
# 0                                       0.597
# 1                                       0.207
# 2                                       0.164
# 3                                       0.135
# 4                                       0.118

# %% [markdown]
# ### PDF-Filenamen wieder einfügen

# %%
pdf_name_files = os.listdir(r"..\Data\Resultate\TF-IDF 40")

pdf_name = []


for file in pdf_name_files:
    if file[-14:-4] == "bow_tf_ifd":
        df_pdf_name = pd.read_csv(
            fr"..\Data\Resultate\TF-IDF 40\{file}", index_col=0) 
        # df_pdf_name = df_simscore_para.rename(columns={"Score": "Paragraphed Cosine Similarity",})      
        new_col = file[:-15]
        # print(new_col)
        idx = 0
        df_pdf_name.insert(loc=idx, column='Company', value=new_col)
        pdf_name.append(df_pdf_name)
        
    else:
        print("didnt work")
df_pdf_name = pd.concat(pdf_name)

# %% [markdown]
# ### Alternative Reports Labeln

# %%
fake_reports = os.listdir(r"..\Data\Nachhaltigkeitsberichte\Fake")
fake_reports_en = []
for report in fake_reports:
    report = report[:-4]
    fake_reports_en.append(report)

german_reports = os.listdir(r"..\Data\Nachhaltigkeitsberichte\DE")
de_reports = []
for report in german_reports:
    report = report[:-4]
    de_reports.append(report)

list_of_name = df_pdf_name["PDF Name"].tolist()

compiler_list = []

for report in list_of_name:
    if report in fake_reports_en:
        print("Fake Report!")
        compiler_list.append("Fake")
    elif report in de_reports:
        print("DE Report!")
        compiler_list.append("DE")
    else:
        compiler_list.append("Normal Report")

df_pdf_name["Report Type"] = compiler_list
# Out:
# Fake Report!
# DE Report!
# DE Report!
# DE Report!
# Fake Report!
# Fake Report!
# DE Report!
# Fake Report!
# Fake Report!

# %%
len(df_pdf_name)
# Out:
# 118

# %%
df_pdf_name[df_pdf_name["Report Type"] == "Fake"]
# Out:
#                   Company                                           PDF Name  \
# 0      america_rome_roman  Ancient Rome Did Not Fall_ Why Real Story is E...
# 0  effective_said_million  How the Collapse of Sam Bankman-Fried’s Crypto...
# 0    football_german_team  Opinion _ Germany’s Coach Is Out of His Depth,...
# 0  palace_race_buckingham  Buckingham Palace race row raises awkward ques...
# 0     team_manager_design  Avoid the Reorg from Hell with Six Key Princip...
#
#                                               TF-IDF  \
# 0  [('goth', 0.2164768687769304), ('with', 0.2105...
# 0  [('disrupted', 0.3463513040823731), ('http', 0...
# 0  [('out', 0.30094334381457943), ('new', 0.30094...
# 0  [('royal', 0.2919344592693881), ('awkward', 0....
# 0  [('hotmail', 0.3193639801508921), ('that', 0.2...
#
#                                          Top N Words            Company Name  \
# 0  [('america', 25), ('rome', 22), ('roman', 20),...      america_rome_roman
# 0  [('effective', 16), ('said', 14), ('million', ...  effective_said_million
# 0  [('football', 10), ('german', 9), ('team', 9),...    football_german_team
# 0  [('palace', 17), ('race', 16), ('buckingham', ...  palace_race_buckingham
# 0  [('team', 42), ('manager', 37), ('design', 28)...     team_manager_design
#
#   Report Type
# 0        Fake
# 0        Fake
# 0        Fake
# 0        Fake
# 0        Fake

# %% [markdown]
# ### Die Dataframes Mergen

# %%
result_zero_shot_fulltext = pd.DataFrame(df_topic_modeler)
result_zero_shot_fulltext
# Out:
#                            Company           Label  Zero Shot Fulltext
# 0   abb_sustainability_performance   social issues            0.249538
# 1   abb_sustainability_performance    human rights            0.226750
# 2   abb_sustainability_performance  sustainability            0.224777
# 3   abb_sustainability_performance      labour law            0.215665
# 4   abb_sustainability_performance           fraud            0.083270
# ..                             ...             ...                 ...
# 0      zurich_commitment_insurance  sustainability            0.380456
# 1      zurich_commitment_insurance    human rights            0.190758
# 2      zurich_commitment_insurance      labour law            0.181221
# 3      zurich_commitment_insurance   social issues            0.176646
# 4      zurich_commitment_insurance           fraud            0.070919
#
# [590 rows x 3 columns]

# %%
# Out:
#                            Company           Label  \
# 0   abb_sustainability_performance  sustainability
# 1   abb_sustainability_performance    human rights
# 2   abb_sustainability_performance           fraud
# 3   abb_sustainability_performance   social issues
# 4   abb_sustainability_performance      labour law
# ..                             ...             ...
# 0      zurich_commitment_insurance  sustainability
# 1      zurich_commitment_insurance    human rights
# 2      zurich_commitment_insurance           fraud
# 3      zurich_commitment_insurance   social issues
# 4      zurich_commitment_insurance      labour law
#
#                       Zero Shot Learning Sentence Raw
# 0   [0.7101063132286072, 0.41432586312294006, 0.50...
# 1   [0.22032485902309418, 0.21426941454410553, 0.1...
# 2   [0.057856060564517975, 0.16787868738174438, 0....
# 3   [0.0063936966471374035, 0.1543944627046585, 0....
# 4   [0.005319107323884964, 0.049131620675325394, 0...
# ..                                                ...
# 0   [0.3816305696964264, 0.8076730966567993, 0.460...
# 1   [0.3158322870731354, 0.17286501824855804, 0.18...
# 2   [0.16614747047424316, 0.011172414757311344, 0....
# 3   [0.11318854987621307, 0.0064867655746638775, 0...
# 4   [0.023201173171401024, 0.0018026498146355152, ...
#
# [590 rows x 3 columns]

# %%
result_df_sentence_cosine_similarity_list_list = pd.merge(result_zero_shot_fulltext, df_sentence_cosine_similarity_list_list, on=["Company", "Label"])
result_df_sentence_cosine_similarity_list_list = pd.merge(result_zero_shot_fulltext, df_sentence_cosine_similarity_list_list, on=["Company", "Label"])
result_df_sentence_cosine_similarity_list_hr = pd.merge(result_df_sentence_cosine_similarity_list_list, df_sentence_cosine_similarity_list_hr, on=["Company", "Label"])
result_df_zero_shot_sentence = pd.merge(result_df_sentence_cosine_similarity_list_hr, df_zero_shot_sentence, on=["Company", "Label"])
result_df_zero_shot_sentence.head()
# Out:
#                           Company           Label  Zero Shot Fulltext  \
# 0  abb_sustainability_performance   social issues            0.249538
# 1  abb_sustainability_performance    human rights            0.226750
# 2  abb_sustainability_performance  sustainability            0.224777
# 3  abb_sustainability_performance      labour law            0.215665
# 4  abb_sustainability_performance           fraud            0.083270
#
#           Sentence Cosine Similarity Wiki Summarized  \
# 0  [tensor([[0.1108]]), tensor([[0.0350]]), tenso...
# 1  [tensor([[0.1447]]), tensor([[0.0357]]), tenso...
# 2  [tensor([[0.3533]]), tensor([[0.0915]]), tenso...
# 3  [tensor([[0.0646]]), tensor([[0.0733]]), tenso...
# 4  [tensor([[-0.0050]]), tensor([[0.0324]]), tens...
#
#    Sentence Cosine Similarity Wiki Summarized Mean  \
# 0                                            0.071
# 1                                            0.078
# 2                                            0.169
# 3                                            0.045
# 4                                           -0.005
#
#    Sentence Cosine Similarity Wiki Summarized Mean Threshold 0  \
# 0                                              0.104
# 1                                              0.114
# 2                                              0.188
# 3                                              0.106
# 4                                              0.062
#
#   Sentence by Sentence Cosine Similarity human rights  \
# 0  [tensor([[0.1108]]), tensor([[0.0350]]), tenso...
# 1  [tensor([[0.1359]]), tensor([[0.0887]]), tenso...
# 2  [tensor([[0.3533]]), tensor([[0.0915]]), tenso...
# 3  [tensor([[0.0646]]), tensor([[0.0733]]), tenso...
# 4  [tensor([[-0.0050]]), tensor([[0.0324]]), tens...
#
#    Sentence by Sentence Cosine Similarity human rights mean  \
# 0                                              0.071
# 1                                              0.098
# 2                                              0.169
# 3                                              0.045
# 4                                             -0.005
#
#    Sentence by Sentence Cosine Similarity human rights Mean Threshold 0  \
# 0                                              0.104
# 1                                              0.125
# 2                                              0.188
# 3                                              0.106
# 4                                              0.062
#
#                      Zero Shot Learning Sentence Raw  \
# 0  [0.0063936966471374035, 0.1543944627046585, 0....
# 1  [0.22032485902309418, 0.21426941454410553, 0.1...
# 2  [0.7101063132286072, 0.41432586312294006, 0.50...
# 3  [0.005319107323884964, 0.049131620675325394, 0...
# 4  [0.057856060564517975, 0.16787868738174438, 0....
#
#    Zero Shot Learning Sentence Mean  \
# 0                             0.086
# 1                             0.161
# 2                             0.597
# 3                             0.044
# 4                             0.112
#
#    Zero Shot Learning Sentence Mean Threshold
# 0                                       0.135
# 1                                       0.207
# 2                                       0.597
# 3                                       0.118
# 4                                       0.164

# %%
final_result = pd.merge(result_df_zero_shot_sentence, df_pdf_name, on=["Company"])
final_result = final_result.drop(['Company Name'], axis=1)
final_result.head()
# Out:
#                           Company           Label  Zero Shot Fulltext  \
# 0  abb_sustainability_performance   social issues            0.249538
# 1  abb_sustainability_performance    human rights            0.226750
# 2  abb_sustainability_performance  sustainability            0.224777
# 3  abb_sustainability_performance      labour law            0.215665
# 4  abb_sustainability_performance           fraud            0.083270
#
#           Sentence Cosine Similarity Wiki Summarized  \
# 0  [tensor([[0.1108]]), tensor([[0.0350]]), tenso...
# 1  [tensor([[0.1447]]), tensor([[0.0357]]), tenso...
# 2  [tensor([[0.3533]]), tensor([[0.0915]]), tenso...
# 3  [tensor([[0.0646]]), tensor([[0.0733]]), tenso...
# 4  [tensor([[-0.0050]]), tensor([[0.0324]]), tens...
#
#    Sentence Cosine Similarity Wiki Summarized Mean  \
# 0                                            0.071
# 1                                            0.078
# 2                                            0.169
# 3                                            0.045
# 4                                           -0.005
#
#    Sentence Cosine Similarity Wiki Summarized Mean Threshold 0  \
# 0                                              0.104
# 1                                              0.114
# 2                                              0.188
# 3                                              0.106
# 4                                              0.062
#
#   Sentence by Sentence Cosine Similarity human rights  \
# 0  [tensor([[0.1108]]), tensor([[0.0350]]), tenso...
# 1  [tensor([[0.1359]]), tensor([[0.0887]]), tenso...
# 2  [tensor([[0.3533]]), tensor([[0.0915]]), tenso...
# 3  [tensor([[0.0646]]), tensor([[0.0733]]), tenso...
# 4  [tensor([[-0.0050]]), tensor([[0.0324]]), tens...
#
#    Sentence by Sentence Cosine Similarity human rights mean  \
# 0                                              0.071
# 1                                              0.098
# 2                                              0.169
# 3                                              0.045
# 4                                             -0.005
#
#    Sentence by Sentence Cosine Similarity human rights Mean Threshold 0  \
# 0                                              0.104
# 1                                              0.125
# 2                                              0.188
# 3                                              0.106
# 4                                              0.062
#
#                      Zero Shot Learning Sentence Raw  \
# 0  [0.0063936966471374035, 0.1543944627046585, 0....
# 1  [0.22032485902309418, 0.21426941454410553, 0.1...
# 2  [0.7101063132286072, 0.41432586312294006, 0.50...
# 3  [0.005319107323884964, 0.049131620675325394, 0...
# 4  [0.057856060564517975, 0.16787868738174438, 0....
#
#    Zero Shot Learning Sentence Mean  \
# 0                             0.086
# 1                             0.161
# 2                             0.597
# 3                             0.044
# 4                             0.112
#
#    Zero Shot Learning Sentence Mean Threshold  \
# 0                                       0.135
# 1                                       0.207
# 2                                       0.597
# 3                                       0.118
# 4                                       0.164
#
#                                            PDF Name  \
# 0  abb-group-sustainability-performance-report-2015
# 1  abb-group-sustainability-performance-report-2015
# 2  abb-group-sustainability-performance-report-2015
# 3  abb-group-sustainability-performance-report-2015
# 4  abb-group-sustainability-performance-report-2015
#
#                                               TF-IDF  \
# 0  [('performance', 0.25703375969085324), ('susta...
# 1  [('performance', 0.25703375969085324), ('susta...
# 2  [('performance', 0.25703375969085324), ('susta...
# 3  [('performance', 0.25703375969085324), ('susta...
# 4  [('performance', 0.25703375969085324), ('susta...
#
#                                          Top N Words    Report Type
# 0  [('abb', 242), ('sustainability', 218), ('perf...  Normal Report
# 1  [('abb', 242), ('sustainability', 218), ('perf...  Normal Report
# 2  [('abb', 242), ('sustainability', 218), ('perf...  Normal Report
# 3  [('abb', 242), ('sustainability', 218), ('perf...  Normal Report
# 4  [('abb', 242), ('sustainability', 218), ('perf...  Normal Report

# %%
len(final_result)
# Out:
# 590

# %% [markdown]
# ### Speichern des Dataframes

# %%
final_result.to_csv(r'..\Data\Resultate\combined_results.csv')
